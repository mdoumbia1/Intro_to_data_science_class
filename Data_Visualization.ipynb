# %% [markdown]
# Matplotlib is the "grandfather" library of data visualization with Python. It was created by John Hunter. He created it to try to replicate MatLab's (another programming language) plotting capabilities in Python. So if you happen to be familiar with matlab, matplotlib will feel natural to you.
#
# It is an excellent 2D and 3D graphics library for generating scientific figures.
#
# Some of the major Pros of Matplotlib are:
#
# * Generally easy to get started for simple plots
# * Support for custom labels and texts
# * Great control of every element in a figure
# * High-quality output in many formats
# * Very customizable in general
#
# Matplotlib allows you to create reproducible figures programmatically. Let's learn how to use it! Before continuing this lecture, I encourage you just to explore the official Matplotlib web page: http://matplotlib.org/
#
# ## Installation
#
# You'll need to install matplotlib first with either:
#
#     conda install matplotlib
# or
#     pip install matplotlib
#
# ## Importing

# %%
# conda install matplotlib

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## If you are note using jupyter notebook

# %% [markdown]
# # Basic Examples

# %%
x = np.linspace(0, 5, 11)
y = x**2

# %%
plt.plot(x,y, 'r')
plt.xlabel('X LABEL')
plt.ylabel('Y LABEL')
plt.title('First Graph in Python')
plt.show()

# %% [markdown]
# # Creating Multiple Plots on Same Canvas Using Function Method

# %%
plt.subplot(1,2,1) 
plt.plot(x, y, 'r--')
plt.subplot(1,2,2)
plt.plot(y, x, 'g*-')

# %% [markdown]
# # Creating Multiple Plots on Same Canvas Using Object Oriented Method

# %%
fig = plt.figure()
axes = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # Left, Bottom, Width and Lenght
axes.plot(x, y, 'b')
axes.set_xlabel('Set X label')
axes.set_ylabel('Set y label')
axes.set_title('Title')
# Out:
# Text(0.5, 1.0, 'Title')

# %%
# Creating two plots inside the same convas

# %%
fig = plt.figure()
# Larger plot
axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])
axes1.plot(x,y, 'b')
axes1.set_xlabel('Set X label_axes1')
axes1.set_ylabel('Set y label_axes1')
axes1.set_title('Larger Plot')

# Smaller plot
axes2 = fig.add_axes([0.2, 0.5, 0.4, 0.3])
axes2.plot(y,x, 'r')
axes2.set_xlabel('Set X label_axes2')
axes2.set_ylabel('Set y label_axes2')
axes2.set_title('Smaller Plot')
# Out:
# Text(0.5, 1.0, 'Smaller Plot')

# %%
fig = plt.figure()
# Larger plot
axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])
# axes1.plot(x,y, 'b')
# axes1.set_xlabel('Set X label_axes1')
# axes1.set_ylabel('Set y label_axes1')
# axes1.set_title('Larger Plot')

# Smaller plot
axes2 = fig.add_axes([0.2, 0.1, 0.5, 0.6])
# axes2.plot(y,x, 'r')
# axes2.set_xlabel('Set X label_axes2')
# axes2.set_ylabel('Set y label_axes2')
# axes2.set_title('Smaller Plot')
